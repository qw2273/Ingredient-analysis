# %% [markdown]
# # Understanding Your Skin Care Product Ingredients

# %% [markdown]
# ## Part I.  Import Modules

# %%
import sys,os
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException

# %%
import statistics  as stat
import pandas as pd
import numpy as np 
import re
from sklearn.manifold import TSNE

# %%
import requests_html
from requests_html import HTMLSession
import string

# %%
import Levenshtein

# %%
root = sys.path[0]

# %% [markdown]
# Notice: Please download the right driver for your browser. [Click to see the guide on driver Installation](https://selenium-python.readthedocs.io/installation.html)

# %%
chrome_path = root + '/chromedriver'
# test if webdriver is installed correctly
#driver_test = webdriver.Chrome(executable_path = chrome_path)

# %% [markdown]
# ## Part II.  Web Scraping

# %% [markdown]
# #### 1. Find infomation on product's name, brand,  price, rating, ingredients

# %% [markdown]
# ##### class scrape_by_category
# - class scrape_by_category has instance variables:
#     - brandname, productname,price,rating,ingredient - infomation for each product
#     - suburl - the product detail page
# - define methods
#     - `__init__`(self, driver,tck, sec, n_scroll)
#         - 1st arg driver - call the browser
#         - 2nd arg tck - specify the category you want to scarpe
#         - 3rd arg sec - specify the seconds to hault the flow of the program,reduce it can decrease
#           processing time
#         - 4th arg n_scroll - specify the number of times when scroll down the each page, reduce it can decrease
#           processing time
#         - brandname,productname,suburl,price, rating,ingredient are all initialized to be empty list
#     - `scrollDown`(self)
#         - scroll down the pages by number of times defined by user
#     - `extractinfo`(self)
#         - for each category page, extract info on products general info
#     - `extract_all_items`(self)
#         - extract detailed information from each product's own page

# %%
class scrape_by_category:
    
    def __init__(self, driver,tck, sec, n_scroll):
        self.driver= driver
        self.sec = sec
        self.tck = tck
        self.brandname,self.productname, self.suburl = [], [] ,  [] 
        self.price, self.rating, self.ingredient = [], [],[]     
        self.n_scroll = n_scroll
        self.url_open = 'https://www.beautypedia.com/skin-care/' + tck + '/?size=96'
    
    def scrollDown(self):
        body = self.driver.find_element_by_tag_name("body")
        while self.n_scroll >= 0:
            body.send_keys(Keys.PAGE_DOWN)
            time.sleep(self.sec)
            self.n_scroll -= 1   
    
    def extractinfo(self):
        xpath =  '//a[@class="review-brand"]'
        for elem in self.driver.find_elements_by_xpath(xpath):
            self.brandname.append(elem.text)     
    
        xpath2 = '//a[@class="review-product"]'    
        for elem in self.driver.find_elements_by_xpath(xpath2):
            self.productname.append(elem.text) 
            self.suburl.append(elem.get_attribute('href') )
            
        return self.brandname, self.productname, self.suburl
    
    def extract_all_items(self):    
        
        self.driver.get(self.url_open)
        # open the first page 
        self.scrollDown()
        self.brandname, self.productname, self.suburl  = self.extractinfo()  
    
        #record the number of pages to be read in total 
        sel_num = Select( self.driver.find_element_by_xpath('//div[@class="page-number"]/select') ) 
        num_pages  = len(sel_num.options)
       
         # for eyecream : look at at most 5 pages to  save processing time 
        # if num_pages >=5: num_pages = 5
    
        # for nighttime and eyecream : only look at 3 pages to  save processing time 
        if num_pages >=3: num_pages = 3
            
        # from 2nd page to last page  
        for i in range(num_pages-1):  
            click_next_xpath = '//div[@class="page-buttons"]/a[@class="page-button next-page"]'
            btn =  self.driver.find_element_by_xpath(click_next_xpath) 
            btn.click()
            time.sleep(self.sec)   
            self.scrollDown()
            self.brandname, self.productname, self.suburl  = self.extractinfo( )  
            time.sleep(self.sec)     
    
    def product_details_extract(self):   
        # call the function to get suburls 
        self.extract_all_items()
    
        # define xpaths 
        xpath2 = '//div[@class="pricing-info"]/span[@class="price"]'
        xpath3 = '//div[@class="expert-rating"]/span'
        xpath4 = '//h3[@class="tab-title ingredients"]'
        xpath5 = '//div[@class="ingredients"]/div'
    
        for i in range(len(self.suburl)):
            # access the url 
            self.driver.get(self.suburl[i])
            time.sleep(self.sec) 
            # extract price info 
            self.price.append(self.driver.find_element_by_xpath(xpath2).text)
            # extract rating
            self.rating.append(self.driver.find_element_by_xpath(xpath3).get_attribute("class")[-1]) 
            # find the expand button, click and extract ingredients info 
            try:
                btn = self.driver.find_element_by_xpath(xpath4)
                self.driver.execute_script("arguments[0].click();", btn)
                btn = self.driver.find_element_by_xpath(xpath4)
                time.sleep(self.sec) 
                self.ingredient.append(self.driver.find_element_by_xpath(xpath5).text) 
            except NoSuchElementException:
                self.ingredient.append('No Info') 
        return self.brandname, self.productname, self.price, self.rating, self.ingredient

# %%
# skin care product type that I am interested in 
ticker = ['moisturizer/daytime-moisturizer-reviews', 'moisturizer/nighttime-moisturizer-reviews',
         'eyes/eye-cream-and-treatment-reviews']

# %%
browser = webdriver.Chrome(executable_path = chrome_path)
dm = scrape_by_category(browser, ticker[0],2, 8) 
t0 = time.time()  
brand_names_1, product_names_1, price_1, rating_1, ingred_1  = dm.product_details_extract()
print("Finished in {} seconds".format( time.time() - t0))
# Out:
# Finished in 5108.163042068481 seconds

# %% [markdown]
# Notice: After runing the above block, I noticed that it takes more than 1 hour to extract inforamtion for about 500 products; therefore when deal with nighttime and product I used 3*96 items, and reduced number of scroll from 8 to 5 then to 2 to further reduce processing time.

# %%
# browser = webdriver.Chrome(executable_path = chrome_path)

# %%
nm = scrape_by_category(browser, ticker[1],2,5) 
t0 = time.time()  
brand_names_2, product_names_2, price_2, rating_2, ingred_2  = nm.product_details_extract()
print("Finished in {} seconds".format( time.time() - t0))
# Out:
# Finished in 3165.4116501808167 seconds

# %%
ec = scrape_by_category(browser, ticker[2],2,2) 
t0 = time.time()  
brand_names_3, product_names_3, price_3, rating_3, ingred_3  = ec.product_details_extract()
print("Finished in {} seconds".format( time.time() - t0))
# Out:
# Finished in 3001.537071943283 seconds

# %%
browser.close()

# %%
len(brand_names_1), len(brand_names_2),len(brand_names_3)
# Out:
# (411, 288, 288)

# %%
# save results to csv 
df_1 = pd.DataFrame(np.column_stack([brand_names_1, product_names_1, price_1, rating_1, ingred_1]))
df_1['label'] = 'DM'


df_2 = pd.DataFrame(np.column_stack([brand_names_2, product_names_2, price_2, rating_2, ingred_2 ]))
df_2['label'] = 'NM'
 
df_3 = pd.DataFrame(np.column_stack([brand_names_3, product_names_3, price_3, rating_3, ingred_3 ]))

df_3['label'] = 'EC'

cosmetic = pd.concat([df_1, df_2],axis = 0 )
cosmetic = pd.concat([cosmetic, df_3],axis = 0 )
cosmetic.columns  = ['brand_name', 'product_name', 'price', 'rating','ingredients', 'label']
cosmetic.to_csv('cosmetic.csv',index = False, encoding='utf-8')

# %%
ingred_name = []
ingred_rating = [] 
lab_list = ["1"] + list(string.ascii_uppercase)

# %%
for lab in lab_list:
    session = HTMLSession()
    r = session.get("https://www.paulaschoice.com/ingredient-dictionary?crefn1=name-first-letter&crefv1=" + lab)
    read_name = r.html.xpath("//td[@class='col-ingredient ingredient-info']/h2[@class='name ingredient-name']/a/text()")
    rating = r.html.xpath("//tr[@class='ingredient-result']/td[1]/text()")
    ingred_name.append(read_name)
    ingred_rating.append(rating)

# %%
ingred_name_lst  = [item.lower() for sublist in ingred_name for item in sublist]
ingred_rating_lst = [item.lower() for sublist in ingred_rating for item in sublist]

# %%
ingredient = pd.DataFrame(list(zip(ingred_name_lst, ingred_rating_lst)))
ingredient.columns = ['name','rating']

# %%
# save to csv
ingred_path  = os.path.join(root, '../doc/ingredient.csv')
ingredient.to_csv(ingred_path,index = False, encoding='utf-8')

# %% [markdown]
# #### processing

# %%
# Load saved csv files
cosm_path = os.path.join(root, '../doc/cosmetic.csv')
ingred_path  = os.path.join(root, '../doc/ingredient.csv')
cosm = pd.read_csv(cosm_path)
ingred_lib =  pd.read_csv(ingred_path)
#cosm.shape
display(cosm.sample(5))
display(ingred_lib.sample(5))
# Out:
#               brand_name                                    product_name  \
# 896         Mally Beauty                   Perfect Prep Soothing Eye Gel
# 465  Youth To The People                   Adaptogen Deep Moisture Cream
# 690     Andalou Naturals              Resveratrol Q10 Night Repair Cream
# 236             Clinique  Redness Solutions Daily Protective Base SPF 15
# 833               CeraVe                                Eye Repair Cream
#
#      price  rating                                        ingredients label
# 896  35.00       2  Water, Butylene Glycol, Methysilanol Mannurona...    EC
# 465  58.00       3  Purified Water, Helianthus Annuus (Sunflower) ...    NM
# 690  24.95       2  Aloe Barbadensis Juice, Vegetable Glycerin, Th...    NM
# 236  22.00       3  Active: Titanium Dioxide (6.4%), Zinc Oxide (2...    DM
# 833  12.99       5  Purified Water, Niacinamide, Cetyl Alcohol, Ca...    EC
#                                                    name rating
# 1327                                     polysorbate 60   good
# 1139                                           oleth-10   good
# 1210  peg-10 dimethicone/vinyl dimethicone crosspolymer   good
# 749                                      grape seed oil   best
# 1725                      trimethylsiloxyamodimethicone   best

# %%
# remove duplicate rows by product name and drop products with no ingredients info 
cosm.drop_duplicates(subset ="product_name",  keep = False, inplace = True) 
cosm = cosm.dropna(how='any', subset=['ingredients'])

# %%
# Only focus analysis on products which has price above its group's median price 
med_price_dict  = {t: stat.median(cosm.loc[cosm['label'] == t, 'price'])  for t in cosm.label.unique() }
sub_cosm  = pd.DataFrame(columns= list(cosm.columns))
for k in med_price_dict.keys():
    subs = cosm[(cosm.label == k ) & (cosm.price >=  med_price_dict.get(k) )]    
    sub_cosm = pd.concat([sub_cosm, subs], axis = 0 )
sub_cosm = sub_cosm.reset_index(drop = True)

# %%
# sub_cosm.ingredients[30:40]

# %%
# for each element in the ingredient find the pair in ingredient lib with minimium levenshtein distance
splitted_ingred_lst = []
for ingred in sub_cosm.ingredients:
   # print('1', ingred)
    pattern1 = re.compile(r"\w+\s*\w+:\s{1}") # remove the words like "Active Ingredients: " 
    ingred = re.sub(pattern1, ', ', ingred)
    
    pattern4 = re.compile(r"\.$")   # remove period at  the end of the ingredients list 
    ingred = re.sub(pattern4, '', ingred)
    
    pattern5 = re.compile(r"[+*\?;\[\]]") 
    ingred = re.sub(pattern5, '',ingred)
    
    pattern6  = re.compile(r"[^0-9]\.")
    ingred = re.sub(pattern6, ' ',ingred)
    
    pattern7 = re.compile(r"\s*\([^\)]+\)") # remove parentheses and text within it 
    ingred = re.sub(pattern7, '', ingred)
    
    #print('3', ingred)
    split_to_list = ingred.split(',')   
    split_to_list = [t.lower().strip(' \t\n\r\[^\(]') for t in  split_to_list  ]   

    splitted_ingred_lst.append(split_to_list)

# %%
ingred_lib['name'][ingred_lib['name'].str.contains('c12-20')]
# Out:
# Series([], Name: name, dtype: object)

# %%
# find matched ingredient in the library 
# reconstruct the ingredient column listed under the original product information page  
update_splitted_ingred_lst = []  
for ingred_list in splitted_ingred_lst:   
    update_ingred_list = []  
    for item in ingred_list:  
        to_add = ""
        if len(item)>3:    
            if re.findall(re.compile("^aqua"),item):
                update_ingred_list.append("water") 
            else: 
                first_five =item[:5]  # the first four letters should be match 
                ingred_lib_sub = list(ingred_lib['name'][ingred_lib['name'].str.contains('^'+first_five)] )
                dist_list = [Levenshtein.distance(l,item) for l in ingred_lib_sub]
                if dist_list:
                    (m,m_i)= min((v,i) for i,v in enumerate(dist_list)) #(min, index)
                    update_ingred_list.append(ingred_lib_sub[m_i]) 
             
    update_splitted_ingred_lst.append(update_ingred_list)

# %%
sub_cosm['ingredient_updated'] = update_splitted_ingred_lst

# %%
display(sub_cosm.sample(5))
# Out:
#         brand_name                                       product_name  price  \
# 146     La Prairie             Cellular Anti-Wrinkle Sun Cream SPF 30  150.0
# 365          belif                              Moisturizing Eye Bomb   48.0
# 230          Ahava               Age Control Even Tone Sleeping Cream   66.0
# 469  SkinCeuticals  Eye Balm Rehabilitative Emollient, for Aging Skin   81.0
# 174    Bobbi Brown              Extra Repair Moisturizing Balm SPF 25   93.0
#
#     rating                                        ingredients label  \
# 146      2  Active: Avobenzone (3%), Octinoxate (7.5%), Oc...    DM
# 365      2  Water, Dipropylene Glycol, Butylene Glycol, Gl...    EC
# 230      2  Aqua (Mineral Spring Water), Hydrogenated Poly...    NM
# 469      2  Deionized Water, Water, Butylene Glycol, Soy B...    EC
# 174      1  Active: Octinoxate (7.5%), Homosalate (5%, Oxy...    DM
#
#                                     ingredient_updated
# 146  [avobenzone, octinoxate, octisalate, octocryle...
# 365  [water, dipropylene glycol, butylene glycol, g...
# 230  [water, hydrogenated polyisobutene, myristyl m...
# 469  [deionized/demineralized water, water, butylen...
# 174  [octinoxate, homosalate, avobenzone, water, c1...

# %% [markdown]
# Now we can see that the ingredient lists are much cleaner, so we can continue our analysis.

# %%
ingredient_idx = {} 
idx = 0
corpus = []  
for ingredient_lst in sub_cosm.ingredient_updated:  
    corpus.append(ingredient_lst)
    for ingredient in ingredient_lst:   
        if ingredient not in ingredient_idx:
                ingredient_idx[ingredient] = idx              
                idx += 1

# %%
# Get the number of items and tokens 
# M: number of cosmetic 
M = len(sub_cosm) 
# N: number of ingredients
N = len(ingredient_idx) 
# Initialize a matrix of zeros
A = np.zeros(shape = (M, N))

# %%
# Define the oh_encoder function
def oh_encoder(tokens):
    x = np.zeros(N)
    for t in tokens:
        # Get the index for each ingredient
        idx = ingredient_idx[t]
        # Put 1 at the corresponding indices
        x[idx] = 1
    return x

# %%
# Make a document-term matrix
# with column represent each ingredient and row represent the each cosmetic
i = 0
for tokens in corpus:
    A[i, :] = oh_encoder(tokens)
    i +=1

# %%
group = sub_cosm.label.unique()
cdict = {'DM': 'red', 'NM': 'blue', 'EC': 'green'}

# %%
# Dimension reduction with t-SNE
# set n_components = 2 for makeing a 2D plot later 
perplexities = [20,50,70,90,100,150, 200]

for i, perplexity in enumerate(perplexities):
    model = TSNE(n_components = 2, perplexity=perplexity  , learning_rate = 200, n_iter=1000, random_state=0)
    tsne_features = model.fit_transform(A)
    sub_cosm['X'] = tsne_features[:, 0]
    sub_cosm['Y'] = tsne_features[:, 1]
    print("plot %d, perplexity = %d"%(i+1, perplexity) )
    
    fig, ax = plt.subplots()
    group = sub_cosm.label.unique()
    cdict = {'DM': 'red', 'NM': 'blue', 'EC': 'green'}
    for g in group:
        ax.scatter(sub_cosm.loc[sub_cosm.label == g, 'X'] , sub_cosm.loc[sub_cosm.label == g, 'Y']  , c = cdict[g], label = g) #, s = 100)
        ax.legend()
    plt.show()
    # Make X, Y columns 
   ## tsne_features[:, 0]
   ## tsne_features[:, 1]
# Out:
# plot 1, perplexity = 20
# plot 2, perplexity = 50
# plot 3, perplexity = 70
# plot 4, perplexity = 90
# plot 5, perplexity = 100
# plot 6, perplexity = 150
# plot 7, perplexity = 200

# %% [markdown]
# From the graph the tsne seeems not performs so well on spliting data according to the its category tbe crowding problem. This is probably because the skincare products themselves do not have a clear cut between one another, from the plot we could see some eye cream product seems to have similar ingredient as daytime moisture, so to solve this, we need something that could be a clear label that distinct one product from another? let's try brand
# The TSne helps to reduce dimension to 2D, the closer the two points are, the more similar they are in ingerdients

# %%
model = TSNE(n_components = 3, perplexity=200, learning_rate = 200, random_state=0)
tsne_features = model.fit_transform(A)
sub_cosm['X'] = tsne_features[:, 0]
sub_cosm['Y'] = tsne_features[:, 1]
sub_cosm['Z'] = tsne_features[:, 2]
fig = plt.figure()
ax = Axes3D(fig)
for g in group:
    ax.scatter(sub_cosm.loc[sub_cosm.label == g, 'X'] , sub_cosm.loc[sub_cosm.label == g, 'Y'] , 
                sub_cosm.loc[sub_cosm.label == g, 'Z'], 
               c = cdict[g])# label = g) #, s = 100)
    #ax.legend()
plt.show()
#ax.scatter3D( c=zdata, cmap='Greens');

# %% [markdown]
# ## Part IV. Visualization

# %%
from bokeh.models import ColumnDataSource, Select, HoverTool
from bokeh.models.widgets import CheckboxGroup
from bokeh.plotting import figure
from bokeh.io import show, output_notebook
from bokeh.layouts import layout, widgetbox, column, row
from bokeh.models import Panel
from bokeh.models.widgets import Tabs

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1554">Loading BokehJS ...</span>
#     </div>

# %%
def bkapp(doc):
     
    # Make the ColumnDataSource: source
    source = ColumnDataSource( sub_cosm ) 
    plot = figure(x_axis_label = 'T-SNE 1', y_axis_label = 'T-SNE 2',plot_height=400, plot_width=500)
    plot.circle(x= 'X', y='Y', alpha = 0.8, source = source)   
    
    # add extract information to each plot 
    hover = HoverTool(tooltips = [
        ('brand', ' @brand_name'),
        ('name', ' @product_name'),
        ('price', ' $ @price'),
        ('rank', ' @rating')])
    plot.add_tools(hover)
    
    rating_lst  = list(sub_cosm.rating.unique())
    rating_lst.sort()  
    rating_lst = [str(r) for r in rating_lst]
   
    def update(attr, old, new):
        if cat_select.value == 'Daytime Moisturizer': c = (sub_cosm.label == 'DM') 
        elif cat_select.value  == 'Eye Cream': c = (sub_cosm.label == 'EC')   
        else: c = (sub_cosm.label == 'NM')  
    
        selected_rating =  [int(checkbox_group.labels[i]) for i in 
                        checkbox_group.active]
         
        df = sub_cosm[c & (sub_cosm.rating.isin(selected_rating))]
        source.data = ColumnDataSource.from_df(df)
        
            
    cat_select = Select(options = ['Daytime Moisturizer','Nighttime Moisturizer','Eye Cream'], 
                        value='Daytime Moisturizer', 
                     title = 'Category')
    
    cat_select.on_change('value', update)
    checkbox_group = CheckboxGroup(labels= 
                                   rating_lst , active=[0,1])
    checkbox_group.on_change('active', update)
    
    
    controls = widgetbox(cat_select, checkbox_group)
    
    # Create a row layout
    layout = row(controls, plot)
    
    # Make a tab with the layout 
    tab = Panel(child=layout, title = 'Select Product Type and Ratings') 
    tabs = Tabs(tabs=[tab])
    doc.add_root(tabs)

# %%
show(bkapp, notebook_url="http://localhost:8904")  # if error， change the notebook_url
# Out:
# <script src="http://localhost:54056/autoload.js?bokeh-autoload-element=1640&bokeh-absolute-url=http://localhost:54056&resources=none" id="1640"></script>
