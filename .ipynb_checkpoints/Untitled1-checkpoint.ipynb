# %% [markdown]
# # Understanding Your Skin Care Product Ingredients

# %% [markdown]
# ## Part I.  Import Modules

# %%
import sys
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException

# %%
import statistics  as stat
import pandas as pd
import numpy as np 
import re
fromsklearn.manifold import TSNE

# %%
root = sys.path[0]

# %% [markdown]
# Notice: Please download the right driver for your browser. [Click to see the guide on driver Installation](https://selenium-python.readthedocs.io/installation.html)

# %%
chrome_path = root + '/chromedriver'
driver_test = webdriver.Chrome(executable_path = chrome_path)
driver_test.close()

# %% [markdown]
# ## Part II.  Web Scraping

# %% [markdown]
# #### 1. Brand Name, Product Name, Sub-url

# %%
def extractinfo(driver, brand, product, suburl):
    '''
    driver: call the webdrivrer
    brand : brand name of products
    product : product name 
    suburl: the urls of product description page 
    '''    
    xpath =  '//a[@class="review-brand"]'
    for elem in driver.find_elements_by_xpath(xpath):
        brand.append( elem.text)     
    
    xpath2 = '//a[@class="review-product"]'    
    for elem in driver.find_elements_by_xpath(xpath2):
        product.append(elem.text) 
        suburl.append(elem.get_attribute('href') )
    
    return brand, product, suburl

# %%
# This function will scroll down the page by number of times defined by user. 
def scrollDown(driver, n_scroll):
    body = driver.find_element_by_tag_name("body")
    while n_scroll >= 0:
        body.send_keys(Keys.PAGE_DOWN)
        time.sleep(2)
        n_scroll -= 1
    return driver

# %%
def extract_all_items( driver, tck):  
    
    # initialize the page and the list to return   
    url_open = 'https://www.beautypedia.com/skin-care/' + tck + '/?size=96'
    driver.get(url_open)
    brandname,productname,suburls = [],[],[]
    
    # collect information on the first page  
    t0 = time.time()  
    brandname, productname, suburls  = extractinfo(driver, brandname,productname,suburls)  
    
    # find the number of pages to be read in total 
    sel_num = Select( driver.find_element_by_xpath('//div[@class="page-number"]/select') ) 
    num_pages  = len(sel_num.options)
    
    # read from 2nd page to last page  
    for i in range(num_pages-1):  
        # continue to next page 
        t0 = time.time()
        click_next_xpath = '//div[@class="page-buttons"]/a[@class="page-button next-page"]'
        btn =  driver.find_element_by_xpath(click_next_xpath) 
        btn.click()
        time.sleep(2)  # wait for fully loading the page      
        browser = scrollDown(driver, 10)
        brandname, productname, suburls  = extractinfo(driver, brandname, productname, suburls)
        time.sleep(2)     
    print("Read {} Pages and Finished in {} seconds".format(num_pages,time.time() - t0))
    return brandname,productname,suburls

# %%
# skin care product type that I am interested in 
ticker = ['moisturizer/daytime-moisturizer-reviews', 'moisturizer/nighttime-moisturizer-reviews',
         'eyes/eye-cream-and-treatment-reviews']

# %%
# day moisture 
browser = webdriver.Chrome(executable_path = chrome_path)
brand_names_1, product_names_1, sub_urls_1  = extract_all_items(browser, ticker[0])
# Out:
# Start Page 1
# Done Page 1
# Start Page 2
# Done Page 2
# Start Page 3
# Done Page 3
# Start Page 4
# Done Page 4
# Start Page 5
# Done Page 5

# %%
# night moisture
browser = webdriver.Chrome(executable_path = chrome_path)
brand_names_2, product_names_2, sub_urls_2  = extract_all_items(browser, ticker[1])
# Out:
# Start Page 1
# Done Page 1
# Start Page 2
# Done Page 2
# Start Page 3
# Done Page 3
# Start Page 4
# Done Page 4
# Start Page 5
# Done Page 5
# Start Page 6
# Done Page 6
# Start Page 7
# Done Page 7
# Start Page 8
# Done Page 8
# Start Page 9
# Done Page 9
# Start Page 10
# Done Page 10
# Start Page 11
# Done Page 11
# Start Page 12
# Done Page 12
# Start Page 13
# Done Page 13

# %%
# eye cream 
browser = webdriver.Chrome(executable_path = chrome_path)
brand_names_3, product_names_3, sub_urls_3  = extract_all_items(browser, ticker[2])
# Out:
# Start Page 1
# Done Page 1
# Start Page 2
# Done Page 2
# Start Page 3
# Done Page 3
# Start Page 4
# Done Page 4
# Start Page 5
# Done Page 5

# %%
# save results to csv 
df_1 = pd.DataFrame(np.column_stack([brand_names_1, product_names_1, sub_urls_1]), columns=['brand_name', 'product_name', 'suburl'])
df_1.to_csv('day_moistrue.csv',index = False, encoding='utf-8')

df_2 = pd.DataFrame(np.column_stack([brand_names_2, product_names_2, sub_urls_2]), columns=['brand_name', 'product_name', 'suburl'])
df_2.to_csv('night_moistrue.csv',index = False, encoding='utf-8')
 
df_3 = pd.DataFrame(np.column_stack([brand_names_3, product_names_3, sub_urls_3]), columns=['brand_name', 'product_name', 'suburl'])
df_3.to_csv('eye_cream.csv',index = False, encoding='utf-8')

# %% [markdown]
# #### 2. Price, Size, Rating, Ingredients

# %%
# Load saved csv files 
day_moist = pd.read_csv('day_moistrue.csv')
night_moist = pd.read_csv('night_moistrue.csv')
eye_cream = pd.read_csv('eye_cream.csv')
# display(day_moist.sample(5)),display(night_moist.sample(5)),display(eye_cream.sample(5))

# %% [markdown]
# function append_new_col is used to extract details of a single product, i.e. price, rating, ingredients

# %%
def append_new_col(driver, df):   
    # initialize the list 
    price, rating, ingredients = [], [],[]     
    # all xpaths 
    xpath2 = '//div[@class="pricing-info"]/span[@class="price"]'
    xpath3 = '//div[@class="expert-rating"]/span'
    xpath4 = '//h3[@class="tab-title ingredients"]'
    xpath5 = '//div[@class="ingredients"]/div'
    
    for i in list(df.index):
        # access the url 
        driver.get(df.suburl[i])
        time.sleep(1) 
        # extract price info 
        price.append(driver.find_element_by_xpath(xpath2).text)
        # extract rating
        rating.append(driver.find_element_by_xpath(xpath3).get_attribute("class")[-1]) 
        # find the expand button, click and extract ingredients info 
        try:
            btn = driver.find_element_by_xpath(xpath4)
            driver.execute_script("arguments[0].click();", btn)
            btn = driver.find_element_by_xpath(xpath4)
            time.sleep(2) 
            ingredients.append(driver.find_element_by_xpath(xpath5).text) 
        except NoSuchElementException:
            ingredients.append('No Info') 
    return  price, rating, ingredients

# %% [markdown]
# To save processing time, instead of using the whole datasets, I deceied to

# %% [markdown]
# For daytime moisture and eyecream, I use whole datasets in  the function  append_new_col
# however, after noticing that the running time is  too long( > 30 miniutes )
# and noticesthe nighttime moisture has over 1000 entries, which is larger than the sum of day moisture and eyecream
# so I decided to randomly sample 250 from night moisture cream

# %%
# ! Notice: The folllowing 3 cells take a long time to run 
browser = webdriver.Chrome(executable_path = chrome_path)
day_moist_price, day_moist_rating, day_moist_ingredients = append_new_col(browser, day_moist)

# %%
browser = webdriver.Chrome(executable_path = chrome_path)
eye_cream_price, eye_cream_rating, eye_cream_ingredients = append_new_col(browser, eye_cream)

# %%
night_moist_part = night_moist.sample(n = 250, replace=False, random_state=1)
browser = webdriver.Chrome(executable_path = chrome_path)
night_moist_price, night_moist_rating, night_moist_ingredients = append_new_col(browser, night_moist_part)

# %%
to_add = pd.DataFrame(np.column_stack([day_moist_price, day_moist_rating, day_moist_ingredients]), columns=['price', 'rating', 'ingredients'])
day_moist_2 = pd.concat([day_moist, to_add], axis = 1)
day_moist_2['label'] =  'DM' # DM: abbrev for Daytime Moisture 
#day_moist_2.to_csv('day_moistrue_2.csv',index = False, encoding='utf-8')

# %%
to_add = pd.DataFrame(np.column_stack([eye_cream_price, eye_cream_rating, eye_cream_ingredients]), columns=['price', 'rating', 'ingredients'])
eye_cream_2 = pd.concat([eye_cream, to_add], axis = 1)
eye_cream_2['label'] =  'EC' # EC: abbrev for Eye Cream
#eye_cream_2.to_csv('eye_cream_2.csv',index = False, encoding='utf-8')

# %%
to_add = pd.DataFrame(np.column_stack([night_moist_price, night_moist_rating, night_moist_ingredients]), columns=['price', 'rating', 'ingredients'])
night_moist_2= pd.concat([night_moist_part.reset_index(drop=True), to_add], axis = 1)
night_moist_2['label'] =  'NM' # NM: abbrev for Night= Moisture 
# night_moist_2.to_csv('night_moisture_2.csv',index = False, encoding='utf-8')

# %%
cosme = pd.concat([day_moist_2, eye_cream_2],axis = 0 )
cosme = pd.concat([cosme, night_moist_2],axis = 0 )
cosme.to_csv('cosmetic.csv',index = False, encoding='utf-8')

# %% [markdown]
# ## Part III. Preprocessing

# %% [markdown]
# #### References
# https://www.datacamp.com/community/tutorials/introduction-t-sne

# %%
# Load saved csv files 
cosm = pd.read_csv('cosmetic.csv')
#display(cosm.sample(10))

# %%
# drop suburls, remove duplicate rows by product name , and drop products with no ingredients info 
cosm = cosm.drop(columns=['suburl'])
cosm.drop_duplicates(subset ="product_name",  keep = False, inplace = True) 
cosm = cosm.dropna(how='any', subset=['ingredients'])

# %%
cosm[cosm.brand_name == 'BeautiControl']
# Out:
#          brand_name                                       product_name  price  \
# 230   BeautiControl  BC Spa Facial Defend & Restore Moisture Creme ...   34.0
# 232   BeautiControl  BC Spa Facial Defend & Restore Moisture Lotion...   34.0
# 575   BeautiControl  Regeneration Tight, Firm & Fill Extreme Eye Co...   65.0
# 671   BeautiControl  Regeneration Tight, Firm & Fill Eye Firming Serum   45.0
# 812   BeautiControl  BC Spa Solutions Under Eye Dark Circle & Puffi...   30.0
# 814   BeautiControl              BC Spa Facial Restructuring Eye Creme   35.0
# 815   BeautiControl   Platinum Regeneration Rejuvenating Eye Treatment   42.0
# 893   BeautiControl         BC Spa Facial Defend & Restore Night Creme   38.0
# 1037  BeautiControl                  Skinlogics Essentials Moisturizer   28.0
#
#       rating                                        ingredients label
# 230        2  Active Ingredients: Homosalate, Oxybenzone, Oc...    DM
# 232        4  Active Ingredient: Titanium Dioxide, Other Ing...    DM
# 575        1  Water, Glycerin, Magnesium Aluminum Silicate, ...    EC
# 671        5  Water, Glycerin, Hexapeptide-10, Palmitoyl Tri...    EC
# 812        1  Water, Butylene Glycol, Propylene Glycol, Glyc...    EC
# 814        1  Water, Caprylic/Capric Triglyceride, Butylene ...    EC
# 815        1  Water, Glycerin, Sodium Polyacrylate, Dipropyl...    EC
# 893        1  Water, Caprylic/Capric Triglyceride, Glycerin,...    NM
# 1037       3  Water, C12-15 Alkyl Benzoate, Caprylic/Capric ...    NM

# %% [markdown]
# For this project, I restrain my analysis on the products whose prices is above the median price within its categorry

# %%
# find the median price for each category 
med_price_dict  = {t: stat.median(cosm.loc[cosm['label'] == t, 'price'])  for t in cosm.label.unique() }

# %%
# subset the cosm dataframe 
sub_cosm  = pd.DataFrame(columns= list(cosm.columns))
for k in med_price_dict.keys():
    subs = cosm[(cosm.label == k ) & (cosm.price >=  med_price_dict.get(k) )]    
    sub_cosm = pd.concat([sub_cosm, subs], axis = 0 )
sub_cosm = sub_cosm.reset_index(drop = True)
# sub_cosm.shape

# %%
ingrednt = [] 
for string in sub_cosm['ingredients']:
    #pattern4 = re.compile(r"|\(|\)")
    #print(string, "\n")
    pattern1 = re.compile(r"\s*\([^\)]+\)") # remove parentheses and text within it 
    string = re.sub(pattern1, '', string)
    pattern2 = re.compile(r"\w+\s*\w+:\s") # remove the words like "Active Ingredients" and parentheses
    string = re.sub(pattern2, '', string)
    pattern3  = re.compile(r"\w+\.*\w*\s*%") # remove percentages 
    string = re.sub(pattern3, '', string)    
    pattern4 = re.compile(r";")   # remove 
    string = re.sub(pattern4, ', ', string)
    pattern5 = re.compile(r"\.{1}\s+") 
    string = re.sub(pattern5, ', ', string)
    pattern6 = re.compile(r"\.$")    
    string = re.sub(pattern6, '', string)
    pattern7 = re.compile(r"\\\s{1}|\/\s{1}")    
    string = re.sub(pattern7, '', string)
    pattern8 = re.compile(r"\\|\/")  
    string = re.sub(pattern8, ' ', string)
    #string = re.sub(pattern8, '', string)
    #print(string, "\n")    
    ingrednt.append(string)

# %%
# Initialize dictionary, list, and initial index
ingredient_idx = {}  #  length of dictionary  indicates how many different ingredients are there  
corpus = []  
idx = 0

# For loop for tokenization
for i in range(len(ingrednt)):
    ingredients = ingrednt[i]  
    
    # token is a list of ingredients for each product 
    split_to_list = ingredients.split(',')
    tokens = [t.lower().strip(' \t\n\r') for t in  split_to_list  ]   
    tokens = [t for t in tokens if len(t)>1 ] # keep those words whose length >1 
    corpus.append(tokens)   # corpus is a list of tokens 
    
    for ingredient in tokens:
        
            
        if ingredient not in ingredient_idx:
            ingredient_idx[ingredient] = idx              
            idx += 1
            
        #else:
            #ingredient_idx[ingredient] += 1  
#sorted (ingredient_idx)

# %%
sorted (ingredient_idx)
# Out:
# ['2 hexanediol',
#  '2 hexanediol& sodium hyaluronate & aqua',
#  '2- hexanediol',
#  '2-0-ethyl ascorbic acid',
#  '2-hexanediol',
#  '2-oleamido-1',
#  '2-oleamindo-1',
#  '2-olemido-1',
#  '3-aminopropane sulfonic acid',
#  '3-hexenol',
#  '3-mthyl-4--3-butne-2-one',
#  '3-o-ethyl ascorbic acid',
#  '3-octadecandiol',
#  '3-octadecanediol',
#  '3-octadedecanediol',
#  '4-t-butylcyclohexanol',
#  '6-naphthalate',
#  '7-dehydrocholesterol',
#  '7-dehydrocholestriol',
#  '? titanium dioxide',
#  '?cetearyl glucoside',
#  '?glycine',
#  '?pentylene glycol',
#  '?xanthan gum',
#  '[+ - mica',
#  '[+ -: iron oxides]',
#  'abies sibirica oil',
#  'acacia dealbata flower wax',
#  'acacia decurrens flower wax',
#  'acacia decurrens jojoba sunflower seed wax polyglyceryl-3 esters',
#  'acacia farnesiana flower wax',
#  'acacia senegal',
#  'acacia senegal gum',
#  'acacia senegal gum extract',
#  'acanthopanax senticosus root extract',
#  'acer saccharinum extract',
#  'acer saccharum extract',
#  'acetic acid',
#  'acetyl carnitine hcl',
#  'acetyl citrull amido arginine',
#  'acetyl decapeptide-3',
#  'acetyl di peptide -1 cetyl ester',
#  'acetyl dipepetide-1 cetyl ester',
#  'acetyl dipeptide-1 cetyl ester',
#  'acetyl farnesylcysteine',
#  'acetyl glucosamine',
#  'acetyl glutamine',
#  'acetyl glutamyl heptapeptide-3',
#  'acetyl heptapeptide-gold',
#  'acetyl hexapaptide-8',
#  'acetyl hexapeptide-20',
#  'acetyl hexapeptide-3',
#  'acetyl hexapeptide-37',
#  'acetyl hexapeptide-8',
#  'acetyl hexapeptode-8',
#  'acetyl hexappetode-8',
#  'acetyl octapeptide-3',
#  'acetyl tetraoeotide-6',
#  'acetyl tetrapeptide platinum',
#  'acetyl tetrapeptide-11',
#  'acetyl tetrapeptide-2',
#  'acetyl tetrapeptide-5',
#  'acetyl tetrapeptide-9',
#  'acetyl tetrapeptode-9',
#  'acetyl trifluoromethylphenyl valyglycine',
#  'acetyl trifluoromethylphenyl valylglycine',
#  'acetyl tyrosine',
#  'acetylated lanolin',
#  'achillea millefolium',
#  'achillea millefolium extract',
#  'achillea millefolium flower extract',
#  'acrylamide',
#  'acrylamide ammonium acrylate copolymer',
#  'acrylamide sodium acrylate copolymer',
#  'acrylamide sodium acrylodimethyltaurate copolymer',
#  'acrylamide sodium acryloyldimethyl taurate copolymer',
#  'acrylamide sodium acryloyldimethyltaurate copolymer',
#  'acrylamide sodiumacryloyldimethyltauratecopolymer',
#  'acrylamidesodium acryloyldimethyltaurate copolymer',
#  'acrylate c10-30 alkyl acrylate crosspolymer',
#  'acrylate crosspolymer',
#  'acrylate sodium acryloyldimethyl taurate copolymer',
#  'acrylates ammonium methacrylate copolymer',
#  'acrylates c 10-30 alkyl acrylate crosspolymer',
#  'acrylates c-10-30 alkyl acrylate crosspolymer',
#  'acrylates c10 30 alkyl acrylate crosspolymer',
#  'acrylates c10-30 alklyl acryalte crosspolymer',
#  'acrylates c10-30 alkyl',
#  'acrylates c10-30 alkyl acrylate crosspolymer',
#  'acrylates c10-30 alkyl acrylates crosspolymer',
#  'acrylates c10-30 alkylacrylate crosspolymer',
#  'acrylates c10-30 crosspolymers',
#  'acrylates c10-c30 alkyl acrylate crosspolymer',
#  'acrylates c12-22 alkyl methacrylate copolymer',
#  'acrylates carbamate copolymer',
#  'acrylates copolymer',
#  'acrylates crosspolymer',
#  'acrylates dimethicone copolymer',
#  'acrylates dimethylaminoethyl methacrylate copolymer',
#  'acrylates steareth-20',
#  'acrylates steareth-20 methacrylate copolymer',
#  'acrylates vinyl isodecanoate crosspolymer',
#  'acrylatesc10-30 alkyl acrylate crosspolymer',
#  'acrylic acid copolymer',
#  'acrylic acid vp crosspolymer',
#  'acteyl triflouromethylphenyl valylglycine',
#  'actinidia chinensis fruit extract',
#  'actinidia polygama fruit extract',
#  'active ingredients:octinoxate',
#  'active:avobenzone',
#  'active:octinoxate',
#  'adansonia digitata fruit extract',
#  'adansonia digitata pulp extract',
#  'adeniumobesum leaf cell extract',
#  'adenosine',
#  'adenosine phosphate',
#  'adenosine triphosphate',
#  'adensoine',
#  'adipic acid diethylene glycol glycerin crosspolymer isohexadecane',
#  'adipic acid diglycol crosspolymer',
#  'adipic acid neopentyl glycol crosspolymer',
#  'aesculus hippocastanum bark extract',
#  'aesculus hippocastanum extract',
#  'aesculus hippocastanum seed extract',
#  'aframomum angustifolium seed extract',
#  'agar',
#  'agarum cribosum extract',
#  'agave tequilana leaf extract',
#  'ahnfeltia concinna extract',
#  'ajuga turkastana extract',
#  'ajuga turkestanica extract',
#  'alanine',
#  'alanine & caprylyl glycol & xanthan gum & ethylhexylglycerin & pseudoalteromonas ferment extract& proline & sodium phosphate & sodium hydroxide & serine',
#  'alaria esculenta extract',
#  'albizia julibrissin bark extract',
#  'alcaligenes polysaccharides',
#  'alchemilla vulgaris extract',
#  'alchemilla vulgaris leaf extract',
#  'alcohol',
#  'alcohol denat',
#  'alcohol denat.',
#  'alcohol denatured',
#  'alcoxa',
#  'alerurites moluccana seed oil',
#  'aleurites moluccana seed oil',
#  'aleuritic acid',
#  'aleuritis moluccana seed oil',
#  'alfalfa extract',
#  'alfalfa seed powder',
#  'algae',
#  'algae exopolysaccharides',
#  'algae exopolysacharides',
#  'algae extract',
#  'algae oligosaccharides',
#  'algin',
#  'alginic acid',
#  'alkanna tinctoria root extract',
#  'alkyl benzoate',
#  'allantoin',
#  'allium cepa bulb extract',
#  'allyl caproate',
#  'allyl methacrylates crosspolymer',
#  'alnus firmifolia fruit extract',
#  'aloe barbadensis',
#  'aloe barbadensis extract',
#  'aloe barbadensis gel',
#  'aloe barbadensis leaf',
#  'aloe barbadensis leaf extract',
#  'aloe barbadensis leaf extract & saccharmyces cerevisiae extract)',
#  'aloe barbadensis leaf juice',
#  'aloe barbadensis leaf juice powder',
#  'aloe vera',
#  'aloe vera extract',
#  'alpha arbutin',
#  'alpha isomethyl ionone',
#  'alpha tocopherol',
#  'alpha-arbutin',
#  'alpha-bisabolol',
#  'alpha-glucan oligosaccharide',
#  'alpha-isomethyl ionone',
#  'alpha-isomethylionone',
#  'alpha-methyl-alpha-ionone',
#  'alphaisomethyl ionone',
#  'alpinia galang leaf extract',
#  'alpinia galanga leaf extract',
#  'alpinia speciosa leaf extract',
#  'alteromonas ferment extract',
#  'althaea officinalis leaf extract',
#  'althaea officinalis leaf root extract',
#  'althaea officinalis root extract',
#  'althaea rosea flower extract',
#  'alumina',
#  'aluminia',
#  'aluminum distarate',
#  'aluminum distearate',
#  'aluminum hydroxide',
#  'aluminum starch octenylsuccinate',
#  'aluminum stearate',
#  'ambrettolide',
#  'amica montana flower extract',
#  'aminobutyric acid',
#  'aminomethyl propanol',
#  'aminopropanediol esters',
#  'aminopropyl ascorbyl phosphate',
#  'aminopropyl dimethicone',
#  'ammonium acryldimethyltaurate steareth-8 methacrylate',
#  'ammonium acryloldimethyltaurate vp copolymer',
#  'ammonium acryloydimethyltaurate vp copolymer',
#  'ammonium acryloyldimethyltaurate',
#  'ammonium acryloyldimethyltaurate  vp copolymer',
#  'ammonium acryloyldimethyltaurate beheneth-25 methacrylate crosspolymer',
#  'ammonium acryloyldimethyltaurate vp copolymer',
#  'ammonium acryloyldimethyltauratebeheneth-25 methacrylate crosspolymer',
#  'ammonium acryloyldimtaurate vp copolymer',
#  'ammonium acryloyldmethyltaurate vp copolymer',
#  'ammonium acryloylmethyltaurate vp copolymer',
#  'ammonium glycolate',
#  'ammonium glycyrrhizate',
#  'ammonium glycyrrhizinate',
#  'ammonium hydroxide',
#  'ammonium polyacrydimethyltauramide ammonium polyacryloyldimethyl taurate',
#  'ammonium polyacrylate',
#  'ammonium polyacryldemithyltauramide',
#  'ammonium polyacryldimethyl taurate',
#  'ammonium polyacryldimethyl-tauramideammonium polyacryloyldimethyl taurate',
#  'ammonium polyacryldimethyltauramide',
#  'ammonium polyacryldimethyltauramide  ammonium polyacryloyldimethyl taurate',
#  'ammonium polyacryldimethyltauramide ammonium polyacryloydimethyltaurate',
#  'ammonium polyacryldimethyltauramide ammonium polyacryloyldimethyl taurate',
#  'ammonium polyacryloyldimethyl taurate',
#  'ammoniumpolyacryldimethyltauramide ammoniumpolyacryloyldimethyl taurate',
#  'amodimethicone',
#  'amorphophallus campanulatus rhizome root extract',
#  'amorphophallus konjac root extract',
#  'amorphophallus konjac root powder',
#  'amy cinnamal',
#  'amyl cinnamal',
#  'amyl salicylate',
#  'amyris balsamifera bark oil',
#  'anacyclus pyrethrum root extract',
#  'ananas sativus fruit extract',
#  'angelica acutiloba root extract',
#  'angelica archangelica root extract',
#  'angelica archangelica root oil',
#  'angelica archangelica root water*',
#  'angelica keiskei extract',
#  'anhydroxylitol',
#  'aniba rosaeodora wood extract',
#  'aniba rosaeodora wood oil',
#  'aniba rosodora wood oil',
#  'anigozanthos flavidus extract',
#  'annatto',
#  'anogeissus leiocarpus bark extract',
#  'anona squamosa seed extract',
#  'anthemis nobilis',
#  'anthemis nobilis flower extract',
#  'anthemis nobilis flower oil',
#  'anthemis nobilis flower water',
#  'anthemis noblis flower extract',
#  'anthyllis vulneraria extract',
#  'aphanizomenon flos-aquae extract',
#  'aplha-isomethyl ionone',
#  'apple fruit extract',
#  'apricot kernel amino acids',
#  'apricot kernel oil',
#  'apricot oil',
#  'aqua',
#  'aqua water',
#  'aqua water eau',
#  'arabidopsis thaliana extract',
#  'arachidonic acid',
#  'arachidyl alcohol',
#  'arachidyl glucoside',
#  'arachidyl propionate',
#  'arachis hypogaea oil',
#  'arbutin',
#  'arctium lappa root extract',
#  'arctostaphylos uva ursi leaf extract',
#  'argana spinosa kernel extract',
#  'argania spinosa kernal oil',
#  'argania spinosa kernel extract',
#  'argania spinosa kernel oil',
#  'argania spinosa leaf extract',
#  'argania spinosa oil',
#  'arginine',
#  'arginine hcl',
#  'arginine hcll',
#  'arginine leontopodium alpinum flower leaf extract',
#  'arginine lysine polypeptide',
#  'arginine pca',
#  'arnica montana flower extract',
#  'arnica montana powder',
#  'artemesia abrotanum flower leaf stem extract1',
#  'artemia extract',
#  'artemia fumaria officinalis flower leaf stem extract',
#  'artemisia absinthium extract',
#  'artemisia princeps leaf extract',
#  'artemisia vulgaris extract',
#  'ascophyllum nodosum extract',
#  'ascorbic acid',
#  'ascorbic acid [citronellol',
#  'ascorbic acid orange citrus limon citrus aurantifolia polypeptides',
#  'ascorbic acid polypeptide',
#  'ascorbic palmitate',
#  'ascorbyl glucoside',
#  'ascorbyl methylsilanol pectinate',
#  'ascorbyl palmitate',
#  'ascorbyl tetraisopalmitate',
#  'ascorbyl tocopheryl maleate',
#  'ascorbylglucoside',
#  'ascrobyl tocopheryl maleate',
#  'asiatic acid',
#  'asiaticoside',
#  'aspalathus linearis leaf extract',
#  'asparagopsis armata extract',
#  'aspartic acid',
#  'aspergillus rice ferment extract',
#  'aspergillus saccharomyces rice ferment filtrate',
#  'astaxanthin',
#  'aster maritima extract',
#  'astragalus membranaceus root extract',
#  'astrocaryum murumuru butter',
#  'astrocaryum murumuru seed butter',
#  'atelocollagen',
#  'atractylodes macrocephala root powder',
#  'avena sativa',
#  'avena sativa bran extract',
#  'avena sativa kernel extract',
#  'avena sativa kernel oil',
#  'avena sativa kernel protein',
#  'avena sativa meal extract',
#  'avena sativa peptide',
#  'avena sativa protein extract',
#  'averrhoa carambola leaf extract',
#  'avobenxone',
#  'avobenzone',
#  'avobenzone  bisabolol',
#  'avobenzone  c12-15 alkyl benzoate',
#  'avobenzone  water eau',
#  'avocado oil',
#  'azadirachta indica seed oil',
#  'bacillus cordyceps sinensis ganoderma lucidum inonotus obliquus lentinus edodes phellinus linteus schizophyllum commune tricholoma matsutake extract ferment filtrate',
#  'bacillus ferment',
#  'bacillus soybean folic acid ferment',
#  'bakuchiol',
#  'balanites roxburghii seed oil',
#  'bamboo leaf stem extract',
#  'bambusa vulgaris',
#  'bambusa vulgaris extract',
#  'bambusa vulgaris leaf stem extract',
#  'baptisia tinctoria root extract',
#  'barium sulfate',
#  'barley extract',
#  'barosma betulina leaf oil',
#  'batyl alcohol',
#  'bearberry extract',
#  'bearberry extract and licorice pth',
#  'beech tree bud extract',
#  'beeswax',
#  "beeswax cera alba cire d'abeille",
#  "beeswax cire d'abeille",
#  'beeswax cyclomethicone',
#  'beet root extract',
#  'beheneth-20',
#  'beheneth-25',
#  'behenic acid',
#  'behenoxy dimethicone',
#  'behenth-20',
#  'behentrimonium chloride',
#  'behenyl alcohol',
#  'bellis perennis flower extract',
#  'benonite',
#  'bentonite',
#  'benzalkonium chloride',
#  'benzethonium chloride',
#  'benzimidazole diamond amidoethylcarbmoxylpropyl polymethylsilsesquioxane',
#  'benzoate',
#  'benzoic acid',
#  'benzophenone-3',
#  'benzophenone-4',
#  'benzophenone-5',
#  'benzoyl alcohol',
#  'benzyl acetate',
#  'benzyl alcohol',
#  'benzyl benzoate',
#  'benzyl salicylate',
#  'benzylidene dimethoxydimethylindanone',
#  'berchemia lineata leaf extract',
#  'bergamot fruit oil',
#  'bertholletia excelsa extract',
#  'bertholletia excelsa seed oil',
#  'beta -glucan',
#  'beta glucan',
#  'beta sitostearol',
#  'beta sitosterol',
#  'beta vulgaris beet root extract',
#  'beta vulgaris root extract',
#  'beta-carotene',
#  'beta-glucan',
#  'beta-ionone',
#  'beta-sitosterol',
#  'betaglucan',
#  'betaine',
#  'betheneth-25',
#  'betula alba bark extract',
#  'betula alba extract',
#  'betula alba juice',
#  'betula alba leaf extract',
#  'betula platyphylla japonica juice',
#  'betula root extract',
#  'bha',
#  'bht',
#  'bidens pilosa extract',
#  'bifida ferment lysate',
#  'bioflavonoids',
#  'biosaccharide gum 1',
#  'biosaccharide gum 4',
#  'biosaccharide gum-1',
#  'biosaccharide gum-2',
#  'biosaccharide gum-4',
#  'biotin',
#  'biotin-o-cyman-5-ol',
#  'birda ferment lydate',
#  'bis-behenyl isostearyl phytosteryl dimer dilinoleyl',
#  'bis-diglyceryl polyacryladipate-2',
#  'bis-diglyceryl polyacyladipate-2',
#  'bis-ethylhexyl hydroxydimethoxy benzylmalonate',
#  'bis-hydroxyethoxypropyl dimethicone',
#  'bis-peg ppg-14 14 dimethicone',
#  'bis-peg ppg-16 16 peg ppg 16 16 dimethicone',
#  'bis-peg ppg-16 16 peg ppg-16 16 dimethicone',
#  'bis-peg-18 methyl ether dimethyl silane',
#  'bis-vinyl dimethicone dimethicone copolymer',
#  'bisabolol',
#  'bisbehenyl isostearyl phytosteryl dimer dilinoleyl dimer delineate',
#  'bisbehenyl isostearyl phytosteryl dimer dilinoleyl dimer dilinoleate',
#  'bismuth oxychloride',
#  'bitter orange flower extract',
#  'bixa orellana seed extract',
#  'black currant leaf extract',
#  'black currant seed oil',
#  'blue 1',
#  'blue 1 lake',
#  'blue no',
#  'blueberry fruit extract',
#  'boerhavia diffusa root extract',
#  'borage seed oil',
#  'borago',
#  'borago officinalis extract1',
#  'borago officinalis seed oil',
#  'boron nitride',
#  'boswellia carterii oil',
#  'boswellia serrata extract',
#  'boswellia serrata resin extract',
#  'brassica campestris sterols',
#  'brassica oleracea acephala leaf extract',
#  'brassica oleracea capitata leaf extract',
#  'brassica oleracea gemmifera extract',
#  'brassica oleracea italica extract',
#  'bromelain',
#  'buddleja davidii extract',
#  'bupleurum falcatum root extract',
#  'butcherbroom extract',
#  'butcherbroom root extract',
#  'butchers broom extract',
#  'butrospermum parkii',
#  'butyl methoxybenzolmethane',
#  'butyl methoxydibensoylmethane',
#  'butyl methoxydibenzoylmethane',
#  'butyl methoxydibenzoylmethane avobenzone',
#  'butyl octyl salicylate',
#  'butyl phenyl methylpropional',
#  'butyl stearate',
#  'butyl-phenyl methylpropional',
#  'butylated pvp',
#  'butylene ethylene styrene copolymer',
#  'butylene glycol',
#  'butylene glycol & hydroxyethylcellulose & sorbitan laurate & acetyl dipeptide-1 cetyl ester',
#  'butylene glycol cocoate',
#  'butylene glycol dicaprylate dicaprate',
#  'butylene gylcol',
#  'butyloctyl',
#  'butyloctyl salicate',
#  'butyloctyl salicylate',
#  'butylparaben',
#  'butylphenyl methylparaben',
#  'butylphenyl methylpropanediol',
#  'butylphenyl methylpropional',
#  'butylylparaben',
#  'butyparaben',
#  'butyphenyl methylpropional',
#  'butyrospermum parkii',
#  'butyrospermum parkii butter',
#  'butyrospermum parkii butter  shea butter',
#  'butyrospermum parkii butter extract',
#  'butyrospermum parkii butter polyglyceryl-3 beeswax',
#  'butyrospermum parkii butter shea butter',
#  'butyrospermum parkii canola oil',
#  'butyrospermum parkii extract',
#  'butyrospermum parkii extract fragrance',
#  'butyrospermum parkii fruit',
#  'butyrospermum parkii oil',
#  'butyrospermum parkii shea butter',
#  'butyrospermum parkii shea butter shea butter',
#  'butyrospermum parkii unsaponifiables',
#  'butyrosperumum parkii',
#  'c-13-14 isoparaffin',
#  'c10-18 triglycerides',
#  'c10-30 cholesterol lanosterol esters',
#  'c11-15 pareth-7',
#  'c12-14 isoparaffin',
#  'c12-14 pareth-12',
#  'c12-15',
#  'c12-15 alcohol benzoate',
#  'c12-15 alkyl banzoate',
#  'c12-15 alkyl benzoate',
#  'c12-15 alkyl ethyhexanoate',
#  'c12-15 alkyl ethylhexanoate',
#  'c12-16 alcohol',
#  'c12-16 alcohols',
#  'c12-20 acid peg-8 ester',
#  'c12-20 alkyl glucoside',
#  'c12-c15 alkyl benzoate',
#  'c12-c20 acid peg-8 ester',
#  'c13-14 isoparaffin',
#  'c13-15 alkane',
#  'c13-16 isoparaffin',
#  'c14-22 alcohols',
#  'c20-22 alcohols',
#  'c20-22 alkyl phosphate',
#  'c20-22 alkylyl phosphate',
#  'c20-40 pareth-10',
#  'c30-38 olefin isopropyl maleate ma copolymer',
#  'c30-45 alkyl cetearyl dimethicone crosspolymer',
#  'c30-45 alkyl dimethicone',
#  'c30-45 alkyldimethylsilyl polypropylsilsesquioxane',
#  'c9-12 alkane',
#  'c9-15 fluoroalcohol phosphate',
#  'cacrocystis pyrifera extract',
#  'caesalpinia spinosa fruit extract',
#  'caesalpinia spinosa gum',
#  'caffeine',
#  'caffeine acetyl glucosamine',
#  'caffeine usp',
#  'calcium aluminum borosilicate',
#  'calcium ascorbate',
#  'calcium carbonate',
#  'calcium chloride',
#  'calcium gluconate',
#  'calcium hydroxymethionine',
#  'calcium ketogluconate',
#  'calcium pantetheine sulfonate',
#  'calcium panthotenate',
#  'calcium pantothenate',
#  'calcium pca',
#  'calcium phosphate',
#  'calcium sodium phosphosilicate',
#  'calcium stearate',
#  'calendula',
#  'calendula flower extract',
#  'calendula officinalis flower extract',
#  'calluna vulgaris extract',
#  'calluna vulgaris flower extract',
#  'calophyllum inophyllum seed oil',
#  'calophyllum tacamahaca seed oil',
#  'camelina sativa seed oil',
#  'camella',
#  'camellia japonica flower extract',
#  'camellia japonica seed oil',
#  'camellia kissi seed oil',
#  'camellia olefiera leaf extract',
#  'camellia oleifera leaf extract',
#  'camellia oleifera seed oil',
#  'camellia sinensis',
#  'camellia sinensis callus culture conditioned media',
#  'camellia sinensis callus culture extract',
#  'camellia sinensis extract',
#  'camellia sinensis flower extract',
#  'camellia sinensis leaf',
#  'camellia sinensis leaf extract',
#  'camellia sinensis leaf extravt',
#  'camellia sinensis leaf powder',
#  'camellia sinensis leaf water',
#  'camellia sinensis polyphenols',
#  'camellia sinensis seed oil',
#  'camellia sinensis seed oil palm oil aminopropanediol esters',
#  'camilla sativa seed oil',
#  'camphanediol',
#  'cananga odorata flower extract',
#  'cananga odorata flower oil',
#  'canarium commune gum oil',
#  'canarium luzonicum gum nonvolatiles',
#  'candelilla jojoba rice bran polyglyceryl-3 esters',
#  'candelilla wax',
#  'candelillia cera euphorbia cerifera eax cire de candelillia',
#  'candellia cera euphorbia cerifera) candellia) wax cire de candellia tocopherol',
#  'canola oil',
#  'cantaurium erythraea extract',
#  'capric caprylic stearic triglyceride',
#  'capric caprylic triglyceride',
#  'capric caprylic triglycerides',
#  'capric myristic stearic triglyceride',
#  'caprooyl phytosphingosine',
#  'caprooyl sphingosine',
#  'caprooyl tetrapeptide-3',
#  'caproyl salicylate',
#  'capryl glycol',
#  'caprylhydroxamic acid',
#  'caprylic capric',
#  'caprylic capric crosspolymers',
#  'caprylic capric myristic stearic triglyceride',
#  'caprylic capric myrstric stearic triglyceride',
#  'caprylic capric stearic triglycerides',
#  'caprylic capric succinic triglyceride',
#  'caprylic capric triglyceride',
#  'caprylic capric triglyceride carbomer',
#  'caprylic capric triglyceride glycerin',
#  'caprylic capric triglycerides',
#  'caprylic capripc myristic stearic triglyceride',
#  'caprylic capris triglyceride',
#  'capryliccapric caprylic triglyceride',
#  'capryliccapric triglyceride',
#  'capryliccapric triglyceride teprenone',
#  'caprylohydroxamic acid',
#  'capryloyl glycerin sebacic acid copolymer',
#  'capryloyl glycine',
#  'capryloyl salicylic acid',
#  'caprylyl capryl glucoside',
#  'caprylyl caprylate caprate',
#  'caprylyl glycol',
#  'caprylyl glycol & 1',
#  'caprylyl methicone',
#  'caprylyl salicylic acid',
#  'caprylyl trimethicone',
#  'carageenan',
#  'caramel',
#  'carbomer',
#  'carbomer 940',
#  'carbomer copolymer type b',
#  'carbomer disodium edta',
#  'carbomer hydroxyethylcellulose',
#  'carbomer papain crosspolymer',
#  'carboxymethyl cellulose',
#  'carica papaya fruit extract',
#  'carmine',
#  'carnitine',
#  'carnitine hcl',
#  'carnosine',
#  'carob fruit extract',
#  'carpylyl glycol',
#  'carrageenan',
#  'carrageenan chondus crispus',
#  'carrot root',
#  'carthamus tinctorious seed oil',
#  'carthamus tinctorius flower extract',
#  'carthamus tinctorius oleosomes',
#  'carthamus tinctorius seed oil',
#  'carthamus tinctorius seedcake extract',
#  'carthamus tinctorus seedcake extract',
#  'carum petroselinum extract',
#  'carum petroselinum seed oil',
#  'cassia alata leaf extract',
#  'cassia angustifolia seed polysaccharide',
#  'castanea sativa extract',
#  'castanea sativa seed extract',
#  'caulerpa lentillifera extract',
#  'caviar extract',
#  'cedrelopsis grevei bark extract',
#  'cedrus atlantica bark extract',
#  'cedrus atlantica bark oil',
#  'cellulose',
#  'cellulose gum',
#  'centarium erythraea extract',
#  'centaurea cyanus flower water',
#  'centauriam erythaea extract',
#  'centaurium erythraea extract',
#  'centaurum erythraea extract',
#  'centella asiatica extract',
#  'centella asiatica leaf extract',
#  'centella asiatica leaf water',
#  'centella asiatica meristem cell culture',
#  'centella asiatica root extract',
#  'cera alba',
#  'cera alba beeswax',
#  'cera alba beeswax cire dabeille',
#  'cera microcristallina',
#  'cera microcristallina microcrystalline wax cire microcristalline',
#  'cera microcristalline wax',
#  'ceramide',
#  'ceramide 1',
#  'ceramide 2',
#  'ceramide 2 sorbitan stearate',
#  'ceramide 3',
#  'ceramide 6 ii',
#  'ceramide 6 li',
#  'ceramide 6-11',
#  'ceramide ap',
#  'ceramide eop',
#  'ceramide eos',
#  'ceramide ng',
#  'ceramide np',
#  'ceramide ns',
#  'ceramide-3',
#  'ceramide6 ii',
#  'ceramides',
#  'ceratonia siliqua gum',
#  'ceresin',
#  'cerium oxide',
#  'cestrum latifolium leaf extract',
#  'ceteareth 20',
#  'ceteareth-12',
#  'ceteareth-20',
#  'ceteareth-25',
#  'ceteareth-6 olivate',
#  'cetearly alcohol',
#  'cetearyl alcohol',
#  'cetearyl alcohol isohexadecane',
#  'cetearyl dimethicone crosspolymer',
#  'cetearyl ethylhexanoate',
#  'cetearyl glucoside',
#  'cetearyl isononanoate',
#  'cetearyl methicone',
#  'cetearyl octanoate',
#  'cetearyl olivate',
#  'cetearyl olivene',
#  'cetearyl palmitate',
#  'cetearyl phosphate',
#  'cetereth-20',
#  'ceteth-10',
#  'ceteth-10 phosphate',
#  'ceteth-2',
#  'ceteth-20',
#  'ceteth-20 ceramide 1',
#  'ceteth-20 phosphate',
#  'ceteth-24',
#  'cethyl alcohol',
#  'cetraria islandica extract',
#  'cetrimonium chloride',
#  'cetyl acid',
#  'cetyl alcohol',
#  'cetyl dimethicone',
#  'cetyl dimethicone copolyol',
#  'cetyl esters',
#  'cetyl ethyhexandate',
#  'cetyl ethylhexanoate',
#  'cetyl hydroxyethylcellulose',
#  'cetyl hydroxyproline palmitamide',
#  'cetyl lactate',
#  'cetyl octanoate',
#  'cetyl palmitate',
#  'cetyl peg ppg 10 1 dimethicone',
#  'cetyl peg ppg-10 1',
#  'cetyl peg ppg-10 1 dimethicone',
#  'cetyl phosphate',
#  'cetyl ricinoleate',
#  'cetyl stearate',
#  'cetyl tranexamate hcl',
#  'cetylhydroxyproline palmitamide',
#  'chameleon plant extract',
#  'chamomile',
#  'chamomilla recutita',
#  'chamomilla recutita extract',
#  'chamomilla recutita flower extract',
#  'chamomilla recutita flower extract1',
#  'chamomilla recutita flower oil',
#  'chamomilla recutita flower water',
#  'chamomilla recutita matricaria flower extract',
#  'chenopodium quinoa seed extract',
#  'chestnut extract',
#  'chestnut seed extract',
#  'chitosan',
#  'chitosan ascorbate',
#  'chlamydomonas extract',
#  'chloeth-24',
#  'chlorella ferment',
#  'chlorella minutissima extract',
#  'chlorella protothecoides oil',
#  'chlorella vularis extract',
#  'chlorella vulgaris extract',
#  'chlorhexadine digluconate',
#  'chlorhexidine',
#  'chlorhexidine digluconate',
#  'chloride',
#  'chlorophyllin copper complex',
#  'chlorophyllin-copper complex',
#  'chlorpenesin',
#  'chlorphenesin',
#  'cholesterol',
#  'cholesterol oleyl carbonate & cholesteryl nanoate & cholesteryl chloride',
#  'cholesterol potassium sulfate',
#  'cholesteryl chloride',
#  'cholesteryl isostearate',
#  'cholesteryl nonanoate',
#  'cholesteryl oleate',
#  'cholesteryl oleyl carbonate',
#  'cholesteryl stearate',
#  'cholestrol',
#  'cholestryl nonanoate',
#  'cholestryl oleate',
#  'choleth-24',
#  'cholorella vulgaris extract',
#  'chondrus crispus',
#  'chondrus crispus extract',
#  'chromium hydroxide green',
#  'chromium oxide greens',
#  'chrysanthellum indicum extract',
#  'chrysanthemum indicum flower extract',
#  'chrysanthemum parthenium extract',
#  'chrysin',
#  'ci 14700 red 4',
#  'ci 16035',
#  'ci 16035 red 40',
#  'ci 19140',
#  'ci 19140 yellow 5',
#  'ci 75470 carmine',
#  'ci 77019',
#  'ci 77120 barium sulfate',
#  'ci 77163 bismuth oxychloride',
#  'ci 77491',
#  'ci 77491 ci 77492 ci 77499 iron oxides',
#  'ci 77491 propylene carbonate',
#  'ci 77492',
#  'ci 77492 iron oxides',
#  'ci 77499',
#  'ci 77499  iron oxides',
#  'ci 77499 iron oxides',
#  'ci 77891',
#  'ci 77891  titanium dioxide',
#  'ci 77891 & mica',
#  'ci 77891 titanium dioxide',
#  'ci 77891titanium dioxide',
#  'cichorium intybus root extract',
#  'cimicifuga racemosa root extract',
#  'cinnamal alcohol',
#  'cinnamic acid',
#  'cinnamido benzylpiperidinyl ethoxypropylbenzamide',
#  'cinnamomum camphora bark oil',
#  'cinnamomum cassia bark extract',
#  'cinnamomum zeylanicum bark extract',
#  'cinnamon extract',
#  'cinnamosma fragrans leaf oil',
#  'cinnamyl alcohol',
#  'cis-3-hexenyl acetate',
#  'citral',
#  'citrate',
#  'citric acid',
#  'citronellol',
#  'citronellol yeast extract',
#  'citruline',
#  'citrulline',
#  'citrullus lanatus',
#  'citrullus lanatus fruit',
#  'citrullus lanatus fruit extract',
#  'citrullus vulgaris fruit extract',
#  'citrus amara flower extract',
#  'citrus aurantifolia extract',
#  'citrus aurantifolia oil',
#  'citrus aurantifolia peel extract',
#  'citrus aurantium amara flower extract',
#  'citrus aurantium amara flower oil bitter orange flower oil',
#  'citrus aurantium amara flower water',
#  'citrus aurantium amara oil',
#  'citrus aurantium amara peel extract',
#  'citrus aurantium amara peel oil',
#  'citrus aurantium bergamia fruit extract',
#  'citrus aurantium bergamia fruit oil',
#  'citrus aurantium dulcis flower extract',
#  'citrus aurantium dulcis flower oil',
#  'citrus aurantium dulcis fruit extract',
#  'citrus aurantium dulcis fruit water',
#  'citrus aurantium dulcis oil',
#  'citrus aurantium dulcis peel extract',
#  'citrus aurantium dulcis peel oil',
#  'citrus aurantium fruit extract',
#  'citrus aurantium tachibana peel extract',
#  'citrus autrantium dulcis peel oil',
#  'citrus grandis peel extract',
#  'citrus grandis peel oil',
#  'citrus grandis seed extract',
#  'citrus grapefruit peel oil',
#  'citrus junos fruit extract',
#  'citrus junos seed extract',
#  'citrus limon peel extract',
#  'citrus medica limonum extract',
#  'citrus medica limonum fruit extract',
#  'citrus medica limonum peel extract',
#  'citrus medica limonum peel oil',
#  'citrus nobilis peel oil',
#  'citrus orange oil',
#  'citrus paradisi peel oil',
#  'citrus reticulata leaf oil',
#  'citrus reticulata peel extract',
#  'citrus reticulata peel oil',
#  'citrus tangerina extract',
#  'citrus tangerina peel oil',
#  'citrus unshiu peel extract',
#  'cladosiphon okamuranus extract',
#  'clophenesin',
#  'clove leaf oil',
#  'clover flower extract',
#  'clyclopentasiloxane',
#  'cocamidopropyl pg-dimonium chloride phosphate',
#  'cocamidopropyl pg_dimonium chloride phosphate',
#  'cochlearia officinalis flower leaf stalk extract',
#  'coco caprylate caprate',
#  'coco-caprylate',
#  'coco-caprylate caprate',
#  'coco-glucoside',
#  'cocoa seed butter',
#  'cocoglycerides',
#  'coconut alcohol',
#  'coconut alkanes',
#  'coconut oil',
#  'cocos nucifera',
#  'cocos nucifera [cocos nucifera oil]',
#  'cocos nucifera fruit extract',
#  'cocos nucifera oil',
#  'cocos nucifera seed butter',
#  'cocoyl pentapeptide-9',
#  'code f.i.l.b165780 2',
#  'codium fragile extract',
#  'codium tomentosum extract',
#  'coenzyme a',
#  'coffea arabica extract',
#  'coffea arabica leaf',
#  'coffea arabica seed extract',
#  'coffea arabica seed oil',
#  'coffea robusta seed extract',
#  'coffee bean powder',
#  'coix lacryma- jobi ma-yuen seed extract',
#  'coleus barbatus extract',
#  'coleus forskohlii root extract',
#  'collagen',
#  'collagen amino acids',
#  'colloidal gold',
#  'colloidal oatmeal',
#  'colostrum',
#  'comfrey extract',
#  'commiphora mukul resin extract',
#  'commiphora myrrha oil',
#  'commiphora pterocarpa leaf cell extract',
#  'coneflower extract',
#  'copaifera officinalis resin',
#  'copernicia cerifera cera carnauba wax',
#  'copernicia cerifera wax',
#  'copolymer',
#  'copper glucomate',
#  'copper gluconate',
#  'copper lysinate prolinate',
#  'copper pca',
#  'copper tripeptide-1',
#  'corallina officinalis extract',
#  'cordyceps sinensis extract',
#  'coriandrum sativum fruit oil',
#  'coriandrum sativum seed extract',
#  'coriandrum sativum seed oil',
#  'corn germ oil',
#  'corn oil',
#  'corn starch',
#  'corn starch modified',
#  'corylus americana seed extract',
#  'corylus avellana extract',
#  'corylus avellana seed oil',
#  'cottonseed oil palm oil',
#  'cottonseed oil palm oil aminopropanediol esters',
#  'coumarin',
#  'crambe maritima extract',
#  'cranberry fruit extract',
#  'crataegus monogyna flower extract',
#  'creatine',
#  'crithmum maritimum extract',
#  'crosspolymer',
#  'crosspolymer-3',
#  'cucumber extract',
#  'cucumber fruit extract',
#  'cucumis melo cantalupensis fruit extract',
#  'cucumis melo fruit extract',
#  'cucumis sativus',
#  'cucumis sativus extract',
#  'cucumis sativus fruit extract',
#  'cucurbita pepo seed extract',
#  'cupressus sempervirens seed extract',
#  'curcuma longa root',
#  'curcuma longa root extract',
#  'curcume longa root extract',
#  'cutaneous lysate',
#  'cyamopsis tetragonoloba gum',
#  'cyanocobalamin',
#  'cyanotis arachnoidea root extract',
#  'cyathea medullaris leaf extract',
#  'cyclic lysophosphatidic acid',
#  'cyclodextrin',
#  'cyclohexasiloxane',
#  'cyclomethicone',
#  'cyclomethicone & propylene carbonate quaternium-18 hectorite',
#  'cyclopentasiloxane',
#  'cyclopentasiloxane & dimethiconol',
#  'cyclopentasiloxane& peg ppg-18 18 dimethicone',
#  'cyclopeptide-5',
#  'cyclotetrasiloxane',
#  ...]

# %%
# Get the number of items and tokens 
M = len(sub_cosm) # M： number of cosmetic 
N =  len(ingredient_idx) # number of ingredients

# Initialize a matrix of zeros
A =  np.zeros(shape = (M, N))

# %%
# Define the oh_encoder function
def oh_encoder(tokens):
    x = np.zeros(N)
    for t in tokens:
        # Get the index for each ingredient
        idx = ingredient_idx[t]
        # Put 1 at the corresponding indices
        x[idx] = 1
    return x

# %%
# Make a document-term matrix
# with column represent each ingredient and row represent the each cosmetic
i = 0
for tokens in corpus:
    A[i, :] = oh_encoder(tokens)
    i +=1

# %%
# Dimension reduction with t-SNE
model = TSNE(n_components = 2, learning_rate = 200)
tsne_features = model.fit_transform(A)
# Make X, Y columns 
sub_cosm['X'] = tsne_features[:, 0]
sub_cosm['Y'] = tsne_features[:, 1]

# %%
sub_cosm.head(20)
# Out:
#                          brand_name  \
# 0                        Supergoop!
# 1   Bare Minerals (Bare Escentuals)
# 2                      Estee Lauder
# 3                          Clinique
# 4                             Vichy
# 5                         Biossance
# 6   Bare Minerals (Bare Escentuals)
# 7                          Clinique
# 8                          Mary Kay
# 9                          Mary Kay
# 10                Peter Thomas Roth
# 11                         Dr. Jart
# 12                       Supergoop!
# 13                         Mary Kay
# 14          Paula's Choice Skincare
# 15                   Drunk Elephant
# 16                   Drunk Elephant
# 17                       philosophy
# 18                            Murad
# 19                           Tatcha
#
#                                          product_name  price rating  \
# 0   Superscreen Daily Moisturizer Broad Spectrum S...   38.0      3
# 1   Skinlongevity Vital Power Moisturizer Broad Sp...   36.0      4
# 2   Perfectionist Pro MultiDefense UV Fluid Broad ...   47.0      4
# 3   For Men Super Energizer Anti-Fatigue Hydrating...   45.0      4
# 4                               Liftactiv Supreme Day   42.0      2
# 5                           Squalane + Mineral SPF 45   39.0      3
# 6   Complexion Rescue Defense Radiant Protective V...   39.0      4
# 7   Clinique Smart Broad Spectrum SPF 15 Custom-Re...   54.0      2
# 8   TimeWise Age Minimize 3D Day Cream SPF 30 Broa...   32.0      3
# 9   TimeWise Age Minimize 3D Day Cream SPF 30 Broa...   32.0      3
# 10     Max Mineral Naked Broad Spectrum SPF 45 Lotion   38.0      5
# 11  Cicapair Tiger Grass Color Correcting Treatmen...   52.0      2
# 12             Unseen Sunscreen Broad Spectrum SPF 40   32.0      4
# 13             TimeWise Day Solution Sunscreen SPF 35   32.0      5
# 14           RESIST Skin-Restoring Moisturizer SPF 50   33.0      5
# 15                Umbra Sheer Physical Defense SPF 30   34.0      5
# 16          Umbra Tinte Physical Daily Defense SPF 30   36.0      5
# 17  take a deep breath oil-free oxygenating gel cr...   37.0      3
# 18  City Skin Age Defense Broad Spectrum SPF 50 Mi...   65.0      5
# 19      SILKEN Pore Perfecting Sunscreen SPF 35 PA+++   65.0      4
#
#                                           ingredients label          X  \
# 0   Active: Avobenzone (2.5%), Homosalate (8%), Oc...    DM   3.455034
# 1   Active Ingredients: Titanium Dioxide 3.28%; Zi...    DM  34.614559
# 2   Active Ingredients: Titanium Dioxide 6.3%; Zin...    DM  27.416128
# 3   Active: Avobenzone 3%, Octisalate 5%. Inactive...    DM  16.093580
# 4   Aqua/Water, Glycerin, Dimethicone, Rhamnose, I...    DM -11.300848
# 5   Active Ingredients: Zinc Oxide 7%, Titanium Di...    DM  14.801427
# 6   Active: Titanium Dioxide 3.28%, Zinc Oxide 12....    DM  34.639011
# 7   Active Ingredients: Avobenzone 3.0%, Octisalat...    DM   2.150798
# 8   Active Ingredients: Avobenzone 3%; Homosalate ...    DM -13.761141
# 9   Active Ingredients: Avobenzone 3%; Homosalate ...    DM -13.763421
# 10  Active: Titanium Dioxide 1.93%, Zinc Oxide 19....    DM  16.655037
# 11  Water, Centella Asiatica Leaf Water, Isononyl ...    DM  10.336111
# 12  Active: Avobenzone (3%), Homosalate (8%), Octi...    DM   5.677828
# 13  Active Ingredients: Avobenzone 2%; Homosalate ...    DM  -5.906286
# 14  Active Ingredients: Avobenzone 3%; Homosalate ...    DM  -1.950961
# 15  Active Ingredient: Zinc Oxide 20%. Ingredients...    DM  30.445145
# 16  Active Ingredient: Zinc Oxide 20%. Inactive In...    DM  30.444452
# 17  Active Ingredients: Avobenzone (2.7%), Octinox...    DM  22.715357
# 18  Active Ingredients: Titanium Dioxide 2.7%, Zin...    DM  12.536157
# 19  Active Ingredients: Zinc Oxide 15%, Octisalate...    DM  20.748787
#
#             Y
# 0   -1.201331
# 1   -8.112528
# 2   -6.382663
# 3   13.575961
# 4   10.473397
# 5   -4.024587
# 6   -8.111431
# 7   13.626324
# 8   16.398550
# 9   16.400072
# 10 -10.019717
# 11 -10.035572
# 12  -6.055191
# 13   6.192421
# 14   9.435083
# 15 -19.348083
# 16 -19.339529
# 17  21.786892
# 18  -4.320829
# 19 -12.624883

# %% [markdown]
# ## Part IV. Visualization

# %%
from bokeh.io import show, output_notebook, push_notebook
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource, HoverTool, Select 
from ipywidgets import interact

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="11961">Loading BokehJS ...</span>
#     </div>

# %%
# Make the ColumnDataSource: source
source = ColumnDataSource( sub_cosm ) 

# Save the minimum and maximum values of the fertility column: xmin, xmax
xmin, xmax = min(sub_cosm.X), max(sub_cosm.X)

# Save the minimum and maximum values of the life expectancy column: ymin, ymax
ymin, ymax = min(sub_cosm.Y), max(sub_cosm.Y)

# Create the figure: plot
plot = figure(x_axis_label = 'T-SNE 1', y_axis_label = 'T-SNE 2',
             plot_height=400, plot_width=500) # ,x_range=(xmin, xmax), y_range=(ymin, ymax)) 
# plot = figure(tools ='box_select, lasso_select')
plot = figure(tools ='lasso_select, reset')
# Add circle glyphs to the plot
plot.circle(x= 'X', y='Y', alpha = 0.8, source = source)
#plot.circle(x= 'X', y='Y',selection_color = 'red', nonselection_fill_alpha = 0.2, 
           # nonselection_fill_color = 'grey', source=source)
# Out:
# GlyphRenderer(id='12022', ...)

# %%
hover = HoverTool(tooltips = [
        ('brand', ' @brand_name'),
        ('name', ' @product_name'),
        ('price', ' $ @price'),
        ('rank', ' @rating')])
plot.add_tools(hover)

# %%
# Define the callback function: update_plot
option_1 = ['Daytime Moisturizer','Nighttime Moisturizer','Eye Cream']
def update(Category = option_1[0]):
    # Set the yr name to slider.value and new_data to source.data
   #  opt = Category
    if Category == 'Daytime Moisturizer': opt = 'DM'
    elif Category == 'Eye Cream': opt = 'EC'
    else: opt = 'NM'
    df = sub_cosm[sub_cosm['label'] == opt]
    new_data = {
        'X' : df['X'],
        'Y' : df['Y'],
        'product_name' : df['product_name'],
        'brand_name' : df['brand_name'],
         'price' : df['price'],
         'rating' : df['rating']
    }
    
    source.data = new_data
    push_notebook() 

# add a select 
#menu = Select(options = ['DM','NM','EC'], value='DM', title = 'Category')

#menu.on_change('value', callback)
#layout = column(menu, plot)
# Attach the callback to the 'value' property of slider
#slider.on_change('value', update_plot)

# %%
interact(update,  Category = option_1)
show(plot, notebook_handle = True)
# Out:
# interactive(children=(Dropdown(description='Category', options=('Daytime Moisturizer', 'Nighttime Moisturizer'…
#   <div class="bk-root" id="7c75f3a3-e502-4e12-9ec8-d72e91b1aeb5" data-root-id="11995"></div>
# <p><code>&lt;Bokeh Notebook handle for <strong>In[1228]</strong>&gt;</code></p>

# %%
#pattern4 = re.compile(r"\s*\(\w*\s*\w*\)\s*")
#pattern4.findall(string)
#string = re.sub(pattern4, '', string)

# %%
# https://www.paulaschoice.com/ingredient-dictionary?crefn1=name-first-letter&crefv1=B 
# ingredient glossary 
# //h2[@class="name ingredient-name"]
